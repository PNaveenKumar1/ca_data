# %%
import numpy as np
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# import warnings
import warnings
warnings.filterwarnings("ignore")

# We will use some methods from the sklearn module
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.model_selection import train_test_split, cross_val_score

# %%
import pandas as pd
import numpy as np
# reading the CSV file
csvFile = pd.read_csv('519_input.csv')
# displaying the contents of the CSV file
df = pd.DataFrame(csvFile)
#df.drop(columns=['D', 'H'])
#data_top = df.head() 
# print(df)
df.loc[df['H'] !='insn per cycle','G'] = '0'
df
# Out:
#                 A          B   C                      D         E      F  G  \
# 0        0.100179       7874 NaN     branch-load-misses  23749149  23.68  0
# 1        0.100179       8631 NaN          branch-misses  27740676  27.67  0
# 2        0.100179        276 NaN       iTLB-load-misses  28265037  28.19  0
# 3        0.100179        624 NaN       dTLB-load-misses  28263118  28.19  0
# 4        0.100179     167252 NaN      dTLB-store-misses  28261375  28.19  0
# ...           ...        ...  ..                    ...       ...    ... ..
# 29067  127.041229  356078654 NaN                 cycles  28580938  28.42  0
# 29068  127.041229  206399471 NaN        L1-dcache-loads  28599007  28.43  0
# 29069  127.041229   29742124 NaN  L1-dcache-load-misses  25610510  25.46  0
# 29070  127.041229      24164 NaN              LLC-loads  21610371  21.49  0
# 29071  127.041229      13246 NaN        LLC-load-misses  20030499  19.92  0
#
#                                H
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# ...                          ...
# 29067                        NaN
# 29068                        NaN
# 29069  of all L1-dcache accesses
# 29070                        NaN
# 29071   of all LL-cache accesses
#
# [29072 rows x 8 columns]

# %%
df = pd.read_csv("519_input.csv")
l=[]
c=0
for i in df["D"]:
    l.append(i)
    c+=1
    if c==23:
        break

l
# Out:
# ['branch-load-misses',
#  'branch-misses',
#  'iTLB-load-misses',
#  'dTLB-load-misses',
#  'dTLB-store-misses',
#  'L1-icache-load-misses',
#  'L1-dcache-load-misses',
#  'l1d_pend_miss.pending_cycles',
#  'l2_rqsts.code_rd_miss',
#  'l2_rqsts.all_demand_miss',
#  'l2_rqsts.demand_data_rd_miss',
#  'l1d_pend_miss.pending_cycles',
#  'l2_rqsts.code_rd_miss',
#  'l2_rqsts.rfo_miss',
#  'cache-misses',
#  'LLC-load-misses',
#  'LLC-store-misses',
#  'instructions',
#  'cycles',
#  'L1-dcache-loads',
#  'L1-dcache-load-misses',
#  'LLC-loads',
#  'LLC-load-misses']

# %%
li=[]
for i in df['B']:
    li.append(i)
print(len(li))
arr=np.array(li)
arr.resize(1264,23)
arr.shape
arr
# Out:
# 29072
# array([[    7874,     8631,      276, ..., 33070370,    34374,    24086],
#        [   10434,     7664,      252, ..., 32895042,    36748,    23664],
#        [    5312,     2844,      200, ..., 27921158,    36328,    18456],
#        ...,
#        [   13988,    12936,      186, ..., 20289999,    39213,    31798],
#        [    1337,     1362,      191, ..., 24220317,    25473,    14284],
#        [    1171,     1226,      165, ..., 29742124,    24164,    13246]])

# %%
df_new = pd.DataFrame(arr, columns =['branch-load-misses',
 'branch-misses',
 'iTLB-load-misses',
 'dTLB-load-misses',
 'dTLB-store-misses',
 'L1-icache-load-misses',
 'L1-dcache-load-misses',
 'l1d_pend_miss.pending_cycles',
 'l2_rqsts.code_rd_miss',
 'l2_rqsts.all_demand_miss',
 'l2_rqsts.demand_data_rd_miss',
 'l1d_pend_miss.pending_cycles',
 'l2_rqsts.code_rd_miss',
 'l2_rqsts.rfo_miss',
 'cache-misses',
 'LLC-load-misses1',
 'LLC-store-misses',
 'instructions',
 'cycles',
 'L1-dcache-loads',
 'L1-dcache-load-misses1',
 'LLC-loads',
 'LLC-load-misses'])
df_new = df_new.replace('<not counted>','0')  
del df_new['L1-dcache-load-misses1']
del df_new['LLC-load-misses1']
del df_new['L1-dcache-loads']
del df_new['LLC-loads']
del df_new['instructions']
del df_new['cycles']
#del df_new['node-load-misses']
#del df_new['node-store-misses']
df_new
# Out:
#       branch-load-misses  branch-misses  iTLB-load-misses  dTLB-load-misses  \
# 0                   7874           8631               276               624
# 1                  10434           7664               252               600
# 2                   5312           2844               200               608
# 3                    804            959               241               457
# 4                    969           2576               251               657
# ...                  ...            ...               ...               ...
# 1259                 712            787               200               636
# 1260                3061           6230               226               764
# 1261               13988          12936               186               668
# 1262                1337           1362               191               759
# 1263                1171           1226               165               860
#
#       dTLB-store-misses  L1-icache-load-misses  L1-dcache-load-misses  \
# 0                167252                  14603               33152267
# 1                143698                  15129               27984031
# 2                161556                  16133               31435948
# 3                160718                  15577               32512429
# 4                133119                  19445               32666533
# ...                 ...                    ...                    ...
# 1259             165594                  15206               28168384
# 1260             165672                  13850               33097953
# 1261             163392                  19003               32819952
# 1262             145568                  15912               32488114
# 1263             124855                  23943               30466600
#
#       l1d_pend_miss.pending_cycles  l2_rqsts.code_rd_miss  \
# 0                         16175544                  13740
# 1                         27159819                  15309
# 2                         13392822                  15196
# 3                         18962941                  13885
# 4                         14990739                  14557
# ...                            ...                    ...
# 1259                      32040930                  15729
# 1260                      12360410                  15838
# 1261                      10329977                  14783
# 1262                      16978634                  14037
# 1263                      16869583                  13959
#
#       l2_rqsts.all_demand_miss  l2_rqsts.demand_data_rd_miss  \
# 0                      1858136                         20161
# 1                      1010889                         16380
# 2                      1222226                         16607
# 3                      1769453                         20244
# 4                      1837555                         18859
# ...                        ...                           ...
# 1259                   1547829                         22068
# 1260                   1865578                         18307
# 1261                   1891855                         19852
# 1262                   1979659                         22201
# 1263                   1853999                         20743
#
#       l1d_pend_miss.pending_cycles  l2_rqsts.code_rd_miss  l2_rqsts.rfo_miss  \
# 0                         12142891                  13671            1728354
# 1                         30821070                  13347            1233963
# 2                         34925679                  13489            1325543
# 3                         36752753                  15084            1321124
# 4                         14021870                  14811            1722248
# ...                            ...                    ...                ...
# 1259                      21342927                  20310            1268792
# 1260                      12489320                  12552            1677937
# 1261                      15941084                  13650            1836838
# 1262                      15176439                  15036            1863811
# 1263                      13803568                  14923            1758604
#
#       cache-misses  LLC-store-misses  LLC-load-misses
# 0          5127449            825291            24086
# 1          5274946           1137493            23664
# 2          6167401           1277132            18456
# 3          5734393           1186262            11177
# 4          5425753           1003391            24140
# ...            ...               ...              ...
# 1259       5430335           1074733            10124
# 1260       5310669           1033064            23494
# 1261       5577032           1012702            31798
# 1262       5558491            999471            14284
# 1263       5154951            835059            13246
#
# [1264 rows x 17 columns]

# %%
li2=[]
for i in df['G']:
    li2.append(i)
li3=[]
for i in range(17,len(li2),23):
    li3.append(li2[i])
df_new['CPI']=li3
df_new
# Out:
#       branch-load-misses  branch-misses  iTLB-load-misses  dTLB-load-misses  \
# 0                   7874           8631               276               624
# 1                  10434           7664               252               600
# 2                   5312           2844               200               608
# 3                    804            959               241               457
# 4                    969           2576               251               657
# ...                  ...            ...               ...               ...
# 1259                 712            787               200               636
# 1260                3061           6230               226               764
# 1261               13988          12936               186               668
# 1262                1337           1362               191               759
# 1263                1171           1226               165               860
#
#       dTLB-store-misses  L1-icache-load-misses  L1-dcache-load-misses  \
# 0                167252                  14603               33152267
# 1                143698                  15129               27984031
# 2                161556                  16133               31435948
# 3                160718                  15577               32512429
# 4                133119                  19445               32666533
# ...                 ...                    ...                    ...
# 1259             165594                  15206               28168384
# 1260             165672                  13850               33097953
# 1261             163392                  19003               32819952
# 1262             145568                  15912               32488114
# 1263             124855                  23943               30466600
#
#       l1d_pend_miss.pending_cycles  l2_rqsts.code_rd_miss  \
# 0                         16175544                  13740
# 1                         27159819                  15309
# 2                         13392822                  15196
# 3                         18962941                  13885
# 4                         14990739                  14557
# ...                            ...                    ...
# 1259                      32040930                  15729
# 1260                      12360410                  15838
# 1261                      10329977                  14783
# 1262                      16978634                  14037
# 1263                      16869583                  13959
#
#       l2_rqsts.all_demand_miss  l2_rqsts.demand_data_rd_miss  \
# 0                      1858136                         20161
# 1                      1010889                         16380
# 2                      1222226                         16607
# 3                      1769453                         20244
# 4                      1837555                         18859
# ...                        ...                           ...
# 1259                   1547829                         22068
# 1260                   1865578                         18307
# 1261                   1891855                         19852
# 1262                   1979659                         22201
# 1263                   1853999                         20743
#
#       l1d_pend_miss.pending_cycles  l2_rqsts.code_rd_miss  l2_rqsts.rfo_miss  \
# 0                         12142891                  13671            1728354
# 1                         30821070                  13347            1233963
# 2                         34925679                  13489            1325543
# 3                         36752753                  15084            1321124
# 4                         14021870                  14811            1722248
# ...                            ...                    ...                ...
# 1259                      21342927                  20310            1268792
# 1260                      12489320                  12552            1677937
# 1261                      15941084                  13650            1836838
# 1262                      15176439                  15036            1863811
# 1263                      13803568                  14923            1758604
#
#       cache-misses  LLC-store-misses  LLC-load-misses   CPI
# 0          5127449            825291            24086  2.09
# 1          5274946           1137493            23664  1.58
# 2          6167401           1277132            18456  1.43
# 3          5734393           1186262            11177  1.60
# 4          5425753           1003391            24140  1.71
# ...            ...               ...              ...   ...
# 1259       5430335           1074733            10124  1.31
# 1260       5310669           1033064            23494  1.41
# 1261       5577032           1012702            31798  1.61
# 1262       5558491            999471            14284  1.87
# 1263       5154951            835059            13246  2.04
#
# [1264 rows x 18 columns]

# %%
# print(df_new['CPI'].astype(float).mean())
for i in list(df_new):
    df_new[i]=df_new[i].replace('0',df_new[i].astype(float).mean())

df_new
# Out:
#       branch-load-misses  branch-misses  iTLB-load-misses  dTLB-load-misses  \
# 0                   7874           8631               276               624
# 1                  10434           7664               252               600
# 2                   5312           2844               200               608
# 3                    804            959               241               457
# 4                    969           2576               251               657
# ...                  ...            ...               ...               ...
# 1259                 712            787               200               636
# 1260                3061           6230               226               764
# 1261               13988          12936               186               668
# 1262                1337           1362               191               759
# 1263                1171           1226               165               860
#
#       dTLB-store-misses  L1-icache-load-misses  L1-dcache-load-misses  \
# 0                167252                  14603               33152267
# 1                143698                  15129               27984031
# 2                161556                  16133               31435948
# 3                160718                  15577               32512429
# 4                133119                  19445               32666533
# ...                 ...                    ...                    ...
# 1259             165594                  15206               28168384
# 1260             165672                  13850               33097953
# 1261             163392                  19003               32819952
# 1262             145568                  15912               32488114
# 1263             124855                  23943               30466600
#
#       l1d_pend_miss.pending_cycles  l2_rqsts.code_rd_miss  \
# 0                         16175544                  13740
# 1                         27159819                  15309
# 2                         13392822                  15196
# 3                         18962941                  13885
# 4                         14990739                  14557
# ...                            ...                    ...
# 1259                      32040930                  15729
# 1260                      12360410                  15838
# 1261                      10329977                  14783
# 1262                      16978634                  14037
# 1263                      16869583                  13959
#
#       l2_rqsts.all_demand_miss  l2_rqsts.demand_data_rd_miss  \
# 0                      1858136                         20161
# 1                      1010889                         16380
# 2                      1222226                         16607
# 3                      1769453                         20244
# 4                      1837555                         18859
# ...                        ...                           ...
# 1259                   1547829                         22068
# 1260                   1865578                         18307
# 1261                   1891855                         19852
# 1262                   1979659                         22201
# 1263                   1853999                         20743
#
#       l1d_pend_miss.pending_cycles  l2_rqsts.code_rd_miss  l2_rqsts.rfo_miss  \
# 0                         12142891                  13671            1728354
# 1                         30821070                  13347            1233963
# 2                         34925679                  13489            1325543
# 3                         36752753                  15084            1321124
# 4                         14021870                  14811            1722248
# ...                            ...                    ...                ...
# 1259                      21342927                  20310            1268792
# 1260                      12489320                  12552            1677937
# 1261                      15941084                  13650            1836838
# 1262                      15176439                  15036            1863811
# 1263                      13803568                  14923            1758604
#
#       cache-misses  LLC-store-misses  LLC-load-misses   CPI
# 0          5127449            825291            24086  2.09
# 1          5274946           1137493            23664  1.58
# 2          6167401           1277132            18456  1.43
# 3          5734393           1186262            11177  1.60
# 4          5425753           1003391            24140  1.71
# ...            ...               ...              ...   ...
# 1259       5430335           1074733            10124  1.31
# 1260       5310669           1033064            23494  1.41
# 1261       5577032           1012702            31798  1.61
# 1262       5558491            999471            14284  1.87
# 1263       5154951            835059            13246  2.04
#
# [1264 rows x 18 columns]

# %%
 df_new.drop(df_new[df_new['CPI'] >= 2.5].index, inplace = True)
df_new.drop(df_new[df_new['CPI'] <= 0.5].index, inplace = True)
df_new
df_new.columns
df_new
# Out:
#       branch-load-misses  branch-misses  iTLB-load-misses  dTLB-load-misses  \
# 0                   7874           8631               276               624
# 1                  10434           7664               252               600
# 2                   5312           2844               200               608
# 3                    804            959               241               457
# 4                    969           2576               251               657
# ...                  ...            ...               ...               ...
# 1259                 712            787               200               636
# 1260                3061           6230               226               764
# 1261               13988          12936               186               668
# 1262                1337           1362               191               759
# 1263                1171           1226               165               860
#
#       dTLB-store-misses  L1-icache-load-misses  L1-dcache-load-misses  \
# 0                167252                  14603               33152267
# 1                143698                  15129               27984031
# 2                161556                  16133               31435948
# 3                160718                  15577               32512429
# 4                133119                  19445               32666533
# ...                 ...                    ...                    ...
# 1259             165594                  15206               28168384
# 1260             165672                  13850               33097953
# 1261             163392                  19003               32819952
# 1262             145568                  15912               32488114
# 1263             124855                  23943               30466600
#
#       l1d_pend_miss.pending_cycles  l2_rqsts.code_rd_miss  \
# 0                         16175544                  13740
# 1                         27159819                  15309
# 2                         13392822                  15196
# 3                         18962941                  13885
# 4                         14990739                  14557
# ...                            ...                    ...
# 1259                      32040930                  15729
# 1260                      12360410                  15838
# 1261                      10329977                  14783
# 1262                      16978634                  14037
# 1263                      16869583                  13959
#
#       l2_rqsts.all_demand_miss  l2_rqsts.demand_data_rd_miss  \
# 0                      1858136                         20161
# 1                      1010889                         16380
# 2                      1222226                         16607
# 3                      1769453                         20244
# 4                      1837555                         18859
# ...                        ...                           ...
# 1259                   1547829                         22068
# 1260                   1865578                         18307
# 1261                   1891855                         19852
# 1262                   1979659                         22201
# 1263                   1853999                         20743
#
#       l1d_pend_miss.pending_cycles  l2_rqsts.code_rd_miss  l2_rqsts.rfo_miss  \
# 0                         12142891                  13671            1728354
# 1                         30821070                  13347            1233963
# 2                         34925679                  13489            1325543
# 3                         36752753                  15084            1321124
# 4                         14021870                  14811            1722248
# ...                            ...                    ...                ...
# 1259                      21342927                  20310            1268792
# 1260                      12489320                  12552            1677937
# 1261                      15941084                  13650            1836838
# 1262                      15176439                  15036            1863811
# 1263                      13803568                  14923            1758604
#
#       cache-misses  LLC-store-misses  LLC-load-misses   CPI
# 0          5127449            825291            24086  2.09
# 1          5274946           1137493            23664  1.58
# 2          6167401           1277132            18456  1.43
# 3          5734393           1186262            11177  1.60
# 4          5425753           1003391            24140  1.71
# ...            ...               ...              ...   ...
# 1259       5430335           1074733            10124  1.31
# 1260       5310669           1033064            23494  1.41
# 1261       5577032           1012702            31798  1.61
# 1262       5558491            999471            14284  1.87
# 1263       5154951            835059            13246  2.04
#
# [1264 rows x 18 columns]

# %%
# Save the dataframe to a CSV file
df_new.to_csv('cp_new_reg1.csv',index=False)
