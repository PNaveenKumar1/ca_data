# %%
print('hi')
# Out:
# hi

# %%
import pandas as pd
import numpy as np
# reading the CSV file
csvFile = pd.read_csv('510_input_new.csv')
# displaying the contents of the CSV file
df = pd.DataFrame(csvFile)
#df.drop(columns=['D', 'H'])
#data_top = df.head() 
# print(df)
df.loc[df['H'] !='insn per cycle','G'] = '0'
df
# Out:
#                 A          B   C                      D         E      F  G  \
# 0        0.200620    1569464 NaN     branch-load-misses  27998299  27.88  0
# 1        0.200620    1560335 NaN          branch-misses  31997620  31.86  0
# 2        0.200620        745 NaN       iTLB-load-misses  27478838  27.36  0
# 3        0.200620       2214 NaN       dTLB-load-misses  31474123  31.34  0
# 4        0.200620       1034 NaN      dTLB-store-misses  32436349  32.30  0
# ...           ...        ...  ..                    ...       ...    ... ..
# 28400  124.172358  348290203 NaN                 cycles  36431742  36.28  0
# 28401  124.172358  351984594 NaN        L1-dcache-loads  32723288  32.58  0
# 28402  124.172358   20715575 NaN  L1-dcache-load-misses  28728325  28.61  0
# 28403  124.172358     421877 NaN              LLC-loads  23999734  23.90  0
# 28404  124.172358      29632 NaN        LLC-load-misses  24001368  23.90  0
#
#                                H
# ...

# %%
li=[]
for i in df['B']:
    li.append(i)
print(len(li))
arr=np.array(li)
arr.resize(1235,23)
arr.shape
arr
# Out:
# 28405
# array([['1569464', '1560335', '745', ..., '26795614', '519109', '25068'],
#        ['1503093', '1534734', '1227', ..., '26038861', '539658', '41834'],
#        ['1496280', '1458745', '673', ..., '24139518', '531510', '30008'],
#        ...,
#        ['391197', '391545', '15799', ..., '20934188', '455818', '10062'],
#        ['359560', '368813', '14326', ..., '20694627', '436454', '22142'],
#        ['372493', '374526', '18725', ..., '20715575', '421877', '29632']],
#       dtype='<U13')

# %%
df_new = pd.DataFrame(arr, columns =['branch-load-misses','branch-misses','iTLB-load-misses','dTLB-load-misses','dTLB-store-misses','L1-icache-load-misses','L1-dcache-load-misses','l1d_pend_miss.pending_cycles','l2_rqsts.code_rd_miss','l2_rqsts.all_demand_miss','l2_rqsts.demand_data_rd_miss','l1d_pend_miss.pending_cycles','l2_rqsts.code_rd_miss','l2_rqsts.rfo_miss','cache-misses','LLC-load-misses','LLC-store-misses','instructions','cycles','L1-dcache-loads','L1-dcache-load-misses1','LLC-loads','LLC-load-misses1'])
#df_new = pd.DataFrame(arr, columns =['branch-load-misses','branch-misses','iTLB-load-misses','dTLB-load-misses','dTLB-store-misses','L1-icache-load-misses','L1-dcache-load-misses','l1d_pend_miss.pending_cycles','l2_rqsts.code_rd_miss','l2_rqsts.all_demand_miss','l2_rqsts.demand_data_rd_miss','l1d_pend_miss.pending_cycles','l2_rqsts.code_rd_miss','l2_rqsts.rfo_miss','cache-misses','LLC-load-misses','LLC-store-misses','instructions','cycles','L1-dcache-loads','L1-dcache-load-misses','LLC-loads','LLC-load-misses'])
df_new = df_new.replace('<not counted>','0')  
del df_new['L1-dcache-load-misses1']
del df_new['LLC-load-misses1']
del df_new['L1-dcache-loads']
del df_new['LLC-loads']
del df_new['instructions']
del df_new['cycles']

df_new
# Out:
#      branch-load-misses branch-misses iTLB-load-misses dTLB-load-misses  \
# 0               1569464       1560335              745             2214
# 1               1503093       1534734             1227             3038
# 2               1496280       1458745              673             1627
# 3               1425028       1424596              682             2004
# 4               1399816       1435720             1173             3581
# ...                 ...           ...              ...              ...
# 1230             406549        405684            18588             3933
# 1231             383474        385321            18047             2323
# 1232             391197        391545            15799             1734
# 1233             359560        368813            14326             3162
# 1234             372493        374526            18725             2261
#
#      dTLB-store-misses L1-icache-load-misses L1-dcache-load-misses  \
# ...

# %%
li2=[]
for i in df['G']:
    li2.append(i)
li3=[]
for i in range(17,len(li2),23):
    li3.append(li2[i])
df_new['CPI']=li3
df_new
# Out:
#      branch-load-misses branch-misses iTLB-load-misses dTLB-load-misses  \
# 0               1569464       1560335              745             2214
# 1               1503093       1534734             1227             3038
# 2               1496280       1458745              673             1627
# 3               1425028       1424596              682             2004
# 4               1399816       1435720             1173             3581
# ...                 ...           ...              ...              ...
# 1230             406549        405684            18588             3933
# 1231             383474        385321            18047             2323
# 1232             391197        391545            15799             1734
# 1233             359560        368813            14326             3162
# 1234             372493        374526            18725             2261
#
#      dTLB-store-misses L1-icache-load-misses L1-dcache-load-misses  \
# ...

# %%
# print(df_new['CPI'].astype(float).mean())
for i in list(df_new):
    df_new[i]=df_new[i].replace('0',df_new[i].astype(float).mean())

df_new
# Out:
#      branch-load-misses branch-misses iTLB-load-misses dTLB-load-misses  \
# 0               1569464       1560335              745             2214
# 1               1503093       1534734             1227             3038
# 2               1496280       1458745              673             1627
# 3               1425028       1424596              682             2004
# 4               1399816       1435720             1173             3581
# ...                 ...           ...              ...              ...
# 1230             406549        405684            18588             3933
# 1231             383474        385321            18047             2323
# 1232             391197        391545            15799             1734
# 1233             359560        368813            14326             3162
# 1234             372493        374526            18725             2261
#
#      dTLB-store-misses L1-icache-load-misses L1-dcache-load-misses  \
# ...

# %%
 df_new.drop(df_new[df_new['CPI'] >= 2.5].index, inplace = True)
df_new.drop(df_new[df_new['CPI'] <= 0.5].index, inplace = True)
df_new
df_new.columns
df_new
# Out:
#      branch-load-misses branch-misses iTLB-load-misses dTLB-load-misses  \
# 0               1569464       1560335              745             2214
# 1               1503093       1534734             1227             3038
# 2               1496280       1458745              673             1627
# 3               1425028       1424596              682             2004
# 4               1399816       1435720             1173             3581
# ...                 ...           ...              ...              ...
# 1217             894995        877349              593            28137
# 1218             839199        813540              646            22962
# 1219             675997        697010             5076            23231
# 1220             874743        902432              930            17326
# 1221             725153        680740             8491            12541
#
#      dTLB-store-misses L1-icache-load-misses L1-dcache-load-misses  \
# ...

# %%
# Save the dataframe to a CSV file
df_new.to_csv('cp_new_reg1.csv',index=False)

# %%
df = pd.read_csv("cp_new_reg1.csv")
df
# Out:
#       branch-load-misses  branch-misses  iTLB-load-misses  dTLB-load-misses  \
# 0                1569464        1560335               745              2214
# 1                1503093        1534734              1227              3038
# 2                1496280        1458745               673              1627
# 3                1425028        1424596               682              2004
# 4                1399816        1435720              1173              3581
# ...                  ...            ...               ...               ...
# 1172              894995         877349               593             28137
# 1173              839199         813540               646             22962
# 1174              675997         697010              5076             23231
# 1175              874743         902432               930             17326
# 1176              725153         680740              8491             12541
#
# ...

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\DELL'

# %%
df
# Out:
#       branch-load-misses  branch-misses  iTLB-load-misses  dTLB-load-misses  \
# 0                1569464        1560335               745              2214
# 1                1503093        1534734              1227              3038
# 2                1496280        1458745               673              1627
# 3                1425028        1424596               682              2004
# 4                1399816        1435720              1173              3581
# ...                  ...            ...               ...               ...
# 1172              894995         877349               593             28137
# 1173              839199         813540               646             22962
# 1174              675997         697010              5076             23231
# 1175              874743         902432               930             17326
# 1176              725153         680740              8491             12541
#
# ...

# %%
pd.read_csv("cp_new_reg1.csv")
# Out:
#       branch-load-misses  branch-misses  iTLB-load-misses  dTLB-load-misses  \
# 0                1569464        1560335               745              2214
# 1                1503093        1534734              1227              3038
# 2                1496280        1458745               673              1627
# 3                1425028        1424596               682              2004
# 4                1399816        1435720              1173              3581
# ...                  ...            ...               ...               ...
# 1172              894995         877349               593             28137
# 1173              839199         813540               646             22962
# 1174              675997         697010              5076             23231
# 1175              874743         902432               930             17326
# 1176              725153         680740              8491             12541
#
# ...
