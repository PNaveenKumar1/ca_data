# %%
#Importing the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# import warnings
import warnings
warnings.filterwarnings("ignore")

# We will use some methods from the sklearn module
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.model_selection import train_test_split, cross_val_score

# %%
df = pd.read_csv("cp_new_reg1.csv")

#del df['branch-misses','iTLB-load-misses','L1-icache-load-misses','LLC-load-misses','LLC-store-misses']
# del df['cache-misses']
# del df['LLC-load-misses']

# %%
# del df['l2_rqsts.all_demand_miss']
# del df['l2_rqsts.demand_data_rd_miss']
# del df['cache-misses']
# del df['LLC-load-misses']
# del df['dTLB-load-misses']

# del df['branch-misses']
# del df['iTLB-load-misses']
# del df['dTLB-store-misses']
# del df['LLC-store-misses']

# del df['branch-load-misses']

# %%
df.head()


df
# Out:
#       branch-load-misses  branch-misses  iTLB-load-misses  dTLB-load-misses  \
# 0                   7874           8631               276               624
# 1                  10434           7664               252               600
# 2                   5312           2844               200               608
# 3                    804            959               241               457
# 4                    969           2576               251               657
# ...                  ...            ...               ...               ...
# 1259                 712            787               200               636
# 1260                3061           6230               226               764
# 1261               13988          12936               186               668
# 1262                1337           1362               191               759
# 1263                1171           1226               165               860
#
#       dTLB-store-misses  L1-icache-load-misses  L1-dcache-load-misses  \
# 0                167252                  14603               33152267
# 1                143698                  15129               27984031
# 2                161556                  16133               31435948
# 3                160718                  15577               32512429
# 4                133119                  19445               32666533
# ...                 ...                    ...                    ...
# 1259             165594                  15206               28168384
# 1260             165672                  13850               33097953
# 1261             163392                  19003               32819952
# 1262             145568                  15912               32488114
# 1263             124855                  23943               30466600
#
#       l1d_pend_miss.pending_cycles  l2_rqsts.code_rd_miss  \
# 0                         16175544                  13740
# 1                         27159819                  15309
# 2                         13392822                  15196
# 3                         18962941                  13885
# 4                         14990739                  14557
# ...                            ...                    ...
# 1259                      32040930                  15729
# 1260                      12360410                  15838
# 1261                      10329977                  14783
# 1262                      16978634                  14037
# 1263                      16869583                  13959
#
#       l2_rqsts.all_demand_miss  l2_rqsts.demand_data_rd_miss  \
# 0                      1858136                         20161
# 1                      1010889                         16380
# 2                      1222226                         16607
# 3                      1769453                         20244
# 4                      1837555                         18859
# ...                        ...                           ...
# 1259                   1547829                         22068
# 1260                   1865578                         18307
# 1261                   1891855                         19852
# 1262                   1979659                         22201
# 1263                   1853999                         20743
#
#       l1d_pend_miss.pending_cycles.1  l2_rqsts.code_rd_miss.1  \
# 0                           12142891                    13671
# 1                           30821070                    13347
# 2                           34925679                    13489
# 3                           36752753                    15084
# 4                           14021870                    14811
# ...                              ...                      ...
# 1259                        21342927                    20310
# 1260                        12489320                    12552
# 1261                        15941084                    13650
# 1262                        15176439                    15036
# 1263                        13803568                    14923
#
#       l2_rqsts.rfo_miss  cache-misses  LLC-store-misses  LLC-load-misses   CPI
# 0               1728354       5127449            825291            24086  2.09
# 1               1233963       5274946           1137493            23664  1.58
# 2               1325543       6167401           1277132            18456  1.43
# 3               1321124       5734393           1186262            11177  1.60
# 4               1722248       5425753           1003391            24140  1.71
# ...                 ...           ...               ...              ...   ...
# 1259            1268792       5430335           1074733            10124  1.31
# 1260            1677937       5310669           1033064            23494  1.41
# 1261            1836838       5577032           1012702            31798  1.61
# 1262            1863811       5558491            999471            14284  1.87
# 1263            1758604       5154951            835059            13246  2.04
#
# [1264 rows x 18 columns]

# %%
scaler = StandardScaler()

# %%
df.shape
# Out:
# (1264, 18)

# %%
print(df.corr())
# Out:
#                                 branch-load-misses  branch-misses  \
# branch-load-misses                        1.000000       0.933913
# branch-misses                             0.933913       1.000000
# iTLB-load-misses                          0.312942       0.283459
# dTLB-load-misses                          0.208068       0.275364
# dTLB-store-misses                        -0.153128      -0.180844
# L1-icache-load-misses                     0.105447       0.149443
# L1-dcache-load-misses                    -0.090590      -0.087633
# l1d_pend_miss.pending_cycles             -0.035248      -0.010764
# l2_rqsts.code_rd_miss                    -0.017564       0.005413
# l2_rqsts.all_demand_miss                 -0.106841      -0.103262
# l2_rqsts.demand_data_rd_miss             -0.321001      -0.326470
# l1d_pend_miss.pending_cycles.1           -0.062449      -0.078437
# l2_rqsts.code_rd_miss.1                   0.028921       0.049626
# l2_rqsts.rfo_miss                        -0.077636      -0.103067
# cache-misses                             -0.111997      -0.194129
# LLC-store-misses                          0.052622      -0.015250
# LLC-load-misses                           0.668652       0.682295
# CPI                                      -0.089303      -0.082732
#
#                                 iTLB-load-misses  dTLB-load-misses  \
# branch-load-misses                      0.312942          0.208068
# branch-misses                           0.283459          0.275364
# iTLB-load-misses                        1.000000          0.327507
# dTLB-load-misses                        0.327507          1.000000
# dTLB-store-misses                      -0.246252         -0.067049
# L1-icache-load-misses                   0.102287          0.456492
# L1-dcache-load-misses                  -0.122666         -0.078023
# l1d_pend_miss.pending_cycles            0.102864          0.093178
# l2_rqsts.code_rd_miss                   0.115727          0.404231
# l2_rqsts.all_demand_miss                0.006652         -0.127302
# l2_rqsts.demand_data_rd_miss            0.130164          0.136355
# l1d_pend_miss.pending_cycles.1         -0.035070          0.110906
# l2_rqsts.code_rd_miss.1                 0.121620          0.324582
# l2_rqsts.rfo_miss                      -0.014071         -0.194079
# cache-misses                           -0.034662         -0.093560
# LLC-store-misses                       -0.034803         -0.059850
# LLC-load-misses                         0.206108          0.190085
# CPI                                    -0.045380         -0.035981
#
#                                 dTLB-store-misses  L1-icache-load-misses  \
# branch-load-misses                      -0.153128               0.105447
# branch-misses                           -0.180844               0.149443
# iTLB-load-misses                        -0.246252               0.102287
# dTLB-load-misses                        -0.067049               0.456492
# dTLB-store-misses                        1.000000              -0.112472
# L1-icache-load-misses                   -0.112472               1.000000
# L1-dcache-load-misses                    0.626922              -0.200909
# l1d_pend_miss.pending_cycles            -0.407641               0.192265
# l2_rqsts.code_rd_miss                    0.005462               0.530719
# l2_rqsts.all_demand_miss                -0.032300              -0.158901
# l2_rqsts.demand_data_rd_miss            -0.116501               0.001505
# l1d_pend_miss.pending_cycles.1           0.225060               0.099034
# l2_rqsts.code_rd_miss.1                 -0.024033               0.316422
# l2_rqsts.rfo_miss                       -0.468007              -0.042209
# cache-misses                            -0.103016              -0.051158
# LLC-store-misses                         0.335983              -0.015461
# LLC-load-misses                         -0.008762               0.012110
# CPI                                     -0.496215               0.005081
#
#                                 L1-dcache-load-misses  \
# branch-load-misses                          -0.090590
# branch-misses                               -0.087633
# iTLB-load-misses                            -0.122666
# dTLB-load-misses                            -0.078023
# dTLB-store-misses                            0.626922
# L1-icache-load-misses                       -0.200909
# L1-dcache-load-misses                        1.000000
# l1d_pend_miss.pending_cycles                -0.831711
# l2_rqsts.code_rd_miss                        0.022594
# l2_rqsts.all_demand_miss                     0.519646
# l2_rqsts.demand_data_rd_miss                 0.177657
# l1d_pend_miss.pending_cycles.1              -0.111809
# l2_rqsts.code_rd_miss.1                      0.030876
# l2_rqsts.rfo_miss                           -0.251731
# cache-misses                                -0.066108
# LLC-store-misses                             0.308872
# LLC-load-misses                              0.076715
# CPI                                         -0.532983
#
#                                 l1d_pend_miss.pending_cycles  \
# branch-load-misses                                 -0.035248
# branch-misses                                      -0.010764
# iTLB-load-misses                                    0.102864
# dTLB-load-misses                                    0.093178
# dTLB-store-misses                                  -0.407641
# L1-icache-load-misses                               0.192265
# L1-dcache-load-misses                              -0.831711
# l1d_pend_miss.pending_cycles                        1.000000
# l2_rqsts.code_rd_miss                               0.017968
# l2_rqsts.all_demand_miss                           -0.642669
# l2_rqsts.demand_data_rd_miss                       -0.141523
# l1d_pend_miss.pending_cycles.1                      0.318970
# l2_rqsts.code_rd_miss.1                            -0.018774
# l2_rqsts.rfo_miss                                   0.088475
# cache-misses                                        0.029837
# LLC-store-misses                                   -0.351426
# LLC-load-misses                                    -0.223214
# CPI                                                 0.461778
#
#                                 l2_rqsts.code_rd_miss  \
# branch-load-misses                          -0.017564
# branch-misses                                0.005413
# iTLB-load-misses                             0.115727
# dTLB-load-misses                             0.404231
# dTLB-store-misses                            0.005462
# L1-icache-load-misses                        0.530719
# L1-dcache-load-misses                        0.022594
# l1d_pend_miss.pending_cycles                 0.017968
# l2_rqsts.code_rd_miss                        1.000000
# l2_rqsts.all_demand_miss                    -0.043139
# l2_rqsts.demand_data_rd_miss                 0.147784
# l1d_pend_miss.pending_cycles.1               0.144987
# l2_rqsts.code_rd_miss.1                      0.456252
# l2_rqsts.rfo_miss                           -0.141377
# cache-misses                                 0.005141
# LLC-store-misses                             0.058775
# LLC-load-misses                              0.004545
# CPI                                         -0.074931
#
#                                 l2_rqsts.all_demand_miss  \
# branch-load-misses                             -0.106841
# branch-misses                                  -0.103262
# iTLB-load-misses                                0.006652
# dTLB-load-misses                               -0.127302
# dTLB-store-misses                              -0.032300
# L1-icache-load-misses                          -0.158901
# L1-dcache-load-misses                           0.519646
# l1d_pend_miss.pending_cycles                   -0.642669
# l2_rqsts.code_rd_miss                          -0.043139
# l2_rqsts.all_demand_miss                        1.000000
# l2_rqsts.demand_data_rd_miss                    0.583762
# l1d_pend_miss.pending_cycles.1                 -0.713936
# l2_rqsts.code_rd_miss.1                         0.073178
# l2_rqsts.rfo_miss                               0.325596
# cache-misses                                   -0.045430
# LLC-store-misses                                0.084482
# LLC-load-misses                                 0.069484
# CPI                                            -0.279090
#
#                                 l2_rqsts.demand_data_rd_miss  \
# branch-load-misses                                 -0.321001
# branch-misses                                      -0.326470
# iTLB-load-misses                                    0.130164
# dTLB-load-misses                                    0.136355
# dTLB-store-misses                                  -0.116501
# L1-icache-load-misses                               0.001505
# L1-dcache-load-misses                               0.177657
# l1d_pend_miss.pending_cycles                       -0.141523
# l2_rqsts.code_rd_miss                               0.147784
# l2_rqsts.all_demand_miss                            0.583762
# l2_rqsts.demand_data_rd_miss                        1.000000
# l1d_pend_miss.pending_cycles.1                     -0.341092
# l2_rqsts.code_rd_miss.1                             0.239308
# l2_rqsts.rfo_miss                                   0.322881
# cache-misses                                        0.077177
# LLC-store-misses                                   -0.052659
# LLC-load-misses                                    -0.327995
# CPI                                                -0.058676
#
#                                 l1d_pend_miss.pending_cycles.1  \
# branch-load-misses                                   -0.062449
# branch-misses                                        -0.078437
# iTLB-load-misses                                     -0.035070
# dTLB-load-misses                                      0.110906
# dTLB-store-misses                                     0.225060
# L1-icache-load-misses                                 0.099034
# L1-dcache-load-misses                                -0.111809
# l1d_pend_miss.pending_cycles                          0.318970
# l2_rqsts.code_rd_miss                                 0.144987
# l2_rqsts.all_demand_miss                             -0.713936
# l2_rqsts.demand_data_rd_miss                         -0.341092
# l1d_pend_miss.pending_cycles.1                        1.000000
# l2_rqsts.code_rd_miss.1                               0.009119
# l2_rqsts.rfo_miss                                    -0.643630
# cache-misses                                          0.263581
# LLC-store-misses                                      0.147862
# LLC-load-misses                                      -0.257086
# CPI                                                   0.002422
#
#                                 l2_rqsts.code_rd_miss.1  l2_rqsts.rfo_miss  \
# branch-load-misses                             0.028921          -0.077636
# branch-misses                                  0.049626          -0.103067
# iTLB-load-misses                               0.121620          -0.014071
# dTLB-load-misses                               0.324582          -0.194079
# dTLB-store-misses                             -0.024033          -0.468007
# L1-icache-load-misses                          0.316422          -0.042209
# L1-dcache-load-misses                          0.030876          -0.251731
# l1d_pend_miss.pending_cycles                  -0.018774           0.088475
# l2_rqsts.code_rd_miss                          0.456252          -0.141377
# l2_rqsts.all_demand_miss                       0.073178           0.325596
# l2_rqsts.demand_data_rd_miss                   0.239308           0.322881
# l1d_pend_miss.pending_cycles.1                 0.009119          -0.643630
# l2_rqsts.code_rd_miss.1                        1.000000          -0.037935
# l2_rqsts.rfo_miss                             -0.037935           1.000000
# cache-misses                                   0.032006          -0.019835
# LLC-store-misses                               0.012836          -0.366348
# LLC-load-misses                                0.045171           0.029058
# CPI                                           -0.123450           0.413463
#
#                                 cache-misses  LLC-store-misses  \
# branch-load-misses                 -0.111997          0.052622
# branch-misses                      -0.194129         -0.015250
# iTLB-load-misses                   -0.034662         -0.034803
# dTLB-load-misses                   -0.093560         -0.059850
# dTLB-store-misses                  -0.103016          0.335983
# L1-icache-load-misses              -0.051158         -0.015461
# L1-dcache-load-misses              -0.066108          0.308872
# l1d_pend_miss.pending_cycles        0.029837         -0.351426
# l2_rqsts.code_rd_miss               0.005141          0.058775
# l2_rqsts.all_demand_miss           -0.045430          0.084482
# l2_rqsts.demand_data_rd_miss        0.077177         -0.052659
# l1d_pend_miss.pending_cycles.1      0.263581          0.147862
# l2_rqsts.code_rd_miss.1             0.032006          0.012836
# l2_rqsts.rfo_miss                  -0.019835         -0.366348
# cache-misses                        1.000000          0.215207
# LLC-store-misses                    0.215207          1.000000
# LLC-load-misses                    -0.208570         -0.095338
# CPI                                -0.035743         -0.682582
#
#                                 LLC-load-misses       CPI
# branch-load-misses                     0.668652 -0.089303
# branch-misses                          0.682295 -0.082732
# iTLB-load-misses                       0.206108 -0.045380
# dTLB-load-misses                       0.190085 -0.035981
# dTLB-store-misses                     -0.008762 -0.496215
# L1-icache-load-misses                  0.012110  0.005081
# L1-dcache-load-misses                  0.076715 -0.532983
# l1d_pend_miss.pending_cycles          -0.223214  0.461778
# l2_rqsts.code_rd_miss                  0.004545 -0.074931
# l2_rqsts.all_demand_miss               0.069484 -0.279090
# l2_rqsts.demand_data_rd_miss          -0.327995 -0.058676
# l1d_pend_miss.pending_cycles.1        -0.257086  0.002422
# l2_rqsts.code_rd_miss.1                0.045171 -0.123450
# l2_rqsts.rfo_miss                      0.029058  0.413463
# cache-misses                          -0.208570 -0.035743
# LLC-store-misses                      -0.095338 -0.682582
# LLC-load-misses                        1.000000 -0.035891
# CPI                                   -0.035891  1.000000

# %%
print(df.describe())
# Out:
#        branch-load-misses  branch-misses  iTLB-load-misses  dTLB-load-misses  \
# count         1264.000000    1264.000000       1264.000000       1264.000000
# mean          4918.604430    4908.960443        212.939082        717.733386
# std           6557.768442    6286.095985         59.875341        128.620740
# min            558.000000     543.000000          0.000000        452.000000
# 25%            859.000000     864.000000        185.000000        647.750000
# 50%           2244.000000    2124.500000        210.000000        701.500000
# 75%           8144.000000    8256.500000        240.250000        756.000000
# max          75887.000000   72198.000000        608.000000       1540.000000
#
#        dTLB-store-misses  L1-icache-load-misses  L1-dcache-load-misses  \
# count        1264.000000            1264.000000           1.264000e+03
# mean       141812.506329           15938.423259           2.836517e+07
# std         22240.648921            4412.171138           4.337739e+06
# min          4740.000000           11641.000000           1.839688e+07
# 25%        125599.500000           13528.500000           2.456700e+07
# 50%        146753.500000           14460.500000           2.970854e+07
# 75%        161368.500000           16561.250000           3.229872e+07
# max        174475.000000           69644.000000           3.410322e+07
#
#        l1d_pend_miss.pending_cycles  l2_rqsts.code_rd_miss  \
# count                  1.264000e+03            1264.000000
# mean                   2.381873e+07           14327.682753
# std                    1.143407e+07            2462.412587
# min                    9.278683e+06           10378.000000
# 25%                    1.494226e+07           12885.500000
# 50%                    2.029117e+07           13641.000000
# 75%                    3.231551e+07           14995.250000
# max                    1.042984e+08           30615.000000
#
#        l2_rqsts.all_demand_miss  l2_rqsts.demand_data_rd_miss  \
# count              1.264000e+03                   1264.000000
# mean               1.564091e+06                  19064.468354
# std                3.160817e+05                   1712.962486
# min                1.975200e+04                  11617.000000
# 25%                1.302072e+06                  17837.000000
# 50%                1.656051e+06                  18984.500000
# 75%                1.847832e+06                  20205.250000
# max                1.987834e+06                  26240.000000
#
#        l1d_pend_miss.pending_cycles.1  l2_rqsts.code_rd_miss.1  \
# count                    1.264000e+03              1264.000000
# mean                     2.377765e+07             14366.320411
# std                      1.164562e+07              2456.411534
# min                      9.281067e+06             10296.000000
# 25%                      1.508477e+07             12860.000000
# 50%                      2.041340e+07             13701.000000
# 75%                      3.155720e+07             14955.500000
# max                      1.303855e+08             30112.000000
#
#        l2_rqsts.rfo_miss  cache-misses  LLC-store-misses  LLC-load-misses  \
# count       1.264000e+03  1.264000e+03      1.264000e+03      1264.000000
# mean        1.530478e+06  5.494752e+06      1.030140e+06     18757.108386
# std         3.095454e+05  3.709499e+05      1.256869e+05      7870.896165
# min         3.418570e+05  4.424100e+06      2.561330e+05      8848.000000
# 25%         1.273145e+06  5.254627e+06      9.348170e+05     11671.500000
# 50%         1.609950e+06  5.463202e+06      1.034236e+06     17950.500000
# 75%         1.808182e+06  5.675718e+06      1.115078e+06     24526.500000
# max         1.963825e+06  1.114865e+07      1.369650e+06     57870.000000
#
#                CPI
# count  1264.000000
# mean      1.754984
# std       0.244016
# min       1.140000
# 25%       1.570000
# 50%       1.810000
# 75%       1.960000
# max       2.120000

# %%
li=['branch-load-misses', 'iTLB-load-misses', 'l1d_pend_miss.pending_cycles', 'l2_rqsts.code_rd_miss', 'l1d_pend_miss.pending_cycles', 'l2_rqsts.code_rd_miss', 'l2_rqsts.rfo_miss']

# %%
X = df[li]

y = df['CPI']

# %%
# scaler = StandardScaler()
# X=scaler.fit_transform(X)
# y =scaler.fit_transform(y)

# %%
from sklearn.preprocessing import minmax_scale
X=minmax_scale(X)
y=minmax_scale(y)

# %%
sns.distplot(df['CPI']);

# %%
sns.pairplot(df, x_vars=li, y_vars='CPI', aspect=1, kind='scatter')
plt.show()

# %%
plt.show()
sns.heatmap(df.corr(), annot=True, fmt=".1f")
# Out:
# <Axes: >

# %%
X_train,X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 100)

# %%
y_train.shape
# Out:
# (1011,)

# %%
y_test.shape
# Out:
# (253,)

# %%
reg_model = linear_model.LinearRegression()

# %%
#Fitting the Multiple Linear Regression model
# reg_model = LinearRegression().fit(X_train, y_train)
# print(f"Linear Regression-Training set score: {reg_model.score(X_train, y_train):.2f}")
# print(f"Linear Regression-Test set score: {reg_model.score(X_test, y_test):.2f}")

# %%
# from sklearn.linear_model import Ridge
# reg_model = Ridge(alpha=0.9).fit(X_train, y_train)
# print(f"Ridge Regression-Training set score: {reg_model.score(X_train, y_train):.2f}")
# print(f"Ridge Regression-Test set score: {reg_model.score(X_test, y_test):.2f}")

# %%
# reg_model=LinearRegression(positive= True)
reg_model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
#Printing the model coefficients
print('Intercept: ',reg_model.intercept_)
# pair the feature names with the coefficients
list(zip(X, reg_model.coef_))
# Out:
# Intercept:  0.19901063924577927
# [(array([0.09712063, 0.45394737, 0.07258351, 0.16613134, 0.07258351,
#          0.16613134, 0.85482389]),
#   0.005362320035846993),
#  (array([0.13110489, 0.41447368, 0.18818352, 0.2436626 , 0.18818352,
#          0.2436626 , 0.55001455]),
#   -0.2281581467210392),
#  (array([0.06310982, 0.32894737, 0.04329776, 0.23807877, 0.04329776,
#          0.23807877, 0.60647682]),
#   0.450236239893555),
#  (array([0.00326567, 0.39638158, 0.10191846, 0.17329644, 0.10191846,
#          0.17329644, 0.60375236]),
#   0.009210686749866068),
#  (array([0.00545607, 0.41282895, 0.06011446, 0.20650294, 0.06011446,
#          0.20650294, 0.85105933]),
#   0.45023623989355477),
#  (array([0.12047153, 0.30427632, 0.09957114, 0.1645995 , 0.09957114,
#          0.1645995 , 0.86593755]),
#   0.009210686749866123),
#  (array([0.07400868, 0.40460526, 0.01346309, 0.1505658 , 0.01346309,
#          0.1505658 , 0.94838862]),
#   0.5038030597907854)]

# %%
#Predicting the Test and Train set result 
y_pred= reg_model.predict(X_test)  
x_pred= reg_model.predict(X_train)

# %%
print("Prediction for test set: {}".format(y_pred))
print()
print("Prediction for train set: {}".format(x_pred))
# Out:
# Prediction for test set: [0.62860672 0.44124349 0.58345168 0.48714311 0.61791954 0.72243159
#  0.39664578 0.70219994 0.78756802 0.82199424 0.83055772 0.67202956
#  0.7944211  0.64624916 0.58415217 0.66207326 0.738733   0.47449078
#  0.45995919 0.65806352 0.64330446 0.39498421 0.84733978 0.52641749
#  0.74910514 0.62194367 0.93013026 0.54684551 0.50580833 0.70920803
#  0.93341388 0.56466167 0.49570649 0.86716825 0.52606621 0.67114582
#  0.6651387  0.7997302  0.72455405 0.81380742 0.40446993 0.70081191
#  0.48458501 0.57866823 0.63489736 0.36031736 0.85691977 0.46703714
#  0.37695484 0.70109445 0.50388454 0.62553652 0.60669254 0.67405538
#  0.59257518 0.74595593 0.70834646 0.6289507  0.42877509 0.77344444
#  0.74417255 0.68249144 0.5945081  0.89184705 0.47098661 0.83090064
#  0.65160621 0.56632247 0.64270432 0.54727493 0.47069154 0.73828787
#  0.50019667 0.63086779 0.50475621 0.51933927 0.40756628 0.80206723
#  0.78155441 0.84214714 0.61169536 0.67605029 0.58436897 0.40694074
#  0.67309004 0.6947347  0.60953834 0.67622971 0.85791428 0.77040517
#  0.35428369 0.74863658 0.56512491 0.63288887 0.57294907 0.58635624
#  0.85146738 0.82610305 0.65784504 0.40610792 0.60559868 0.41946343
#  0.65683089 0.54708567 0.48248643 0.80578095 0.80062988 0.63381715
#  0.80464217 0.80260527 0.70857452 0.48318138 0.70121319 0.42454389
#  0.42075314 0.67853477 0.72553933 0.3316652  0.66328946 0.47789982
#  0.44168229 0.63121917 0.64376446 0.85228379 0.62767438 0.71765077
#  0.73565289 0.57105941 0.5924443  0.44469677 0.46983773 0.92826285
#  1.0150743  0.82496249 0.60958483 0.49526292 0.69139592 0.64251352
#  0.45652393 0.66688419 0.61564588 0.43707798 0.59155139 0.39641343
#  0.45140413 0.65708475 0.53545874 0.61283341 0.70522882 0.60664626
#  0.626604   0.78048229 0.64848489 0.56965548 0.57423612 0.58162
#  0.54271427 0.89635614 0.70936096 0.69294965 0.36611165 0.55591632
#  0.31512413 0.60758883 0.51490782 0.84383968 0.62052242 0.82019312
#  0.32356254 0.69989734 0.65674795 0.63584075 0.71078864 0.73163421
#  0.71918199 0.65844923 0.48150776 0.81180083 0.42262725 0.64282951
#  0.54854721 0.55622058 0.79179127 0.8291854  0.50406486 0.62624015
#  0.61624338 0.59382853 0.76141041 0.74572448 0.57733584 0.825815
#  0.5957839  0.46972764 0.55367878 0.37389011 0.68717583 0.50016315
#  0.52398732 0.76809691 0.58736311 0.6663601  0.69314664 0.64901378
#  0.62478787 0.76224503 0.42616394 0.64432394 0.57621321 0.49041548
#  0.80884172 0.82106544 0.90299178 0.76391593 0.44180939 0.55079498
#  0.81216874 0.63208833 0.60446295 0.68404454 0.60699205 0.673477
#  0.84200077 0.68102924 0.76436951 0.53312467 0.61380225 0.92336456
#  0.62119725 0.46724365 0.83075214 0.4936234  0.44349827 0.82512511
#  0.5374403  0.83621872 0.65504903 0.82715021 0.47874177 0.62069309
#  0.41155725 0.6228558  0.4534653  0.66527777 0.65524565 0.7772547
#  0.67459928 0.69495961 0.69766844 0.62388384 0.86366987 0.42960649
#  0.94470832]
#
# Prediction for train set: [0.65789749 0.31848361 0.49737917 ... 0.51639004 0.45446814 0.38964661]

# %%
#Actual value and the predicted value
reg_model_diff = pd.DataFrame({'Actual value': y_test, 'Predicted value': y_pred , '  Residue': y_test-y_pred})

# %%
mae = metrics.mean_absolute_error(y_test, y_pred)
mse = metrics.mean_squared_error(y_test, y_pred)
r2 = np.sqrt(metrics.mean_squared_error(y_test, y_pred))
r_squared = reg_model.score(X, y)


print('Mean Absolute Error:', mae)
print('Mean Square Error:', mse)
print('Root Mean Square Error:', r2)
print('R^2 value :', r_squared)
print('F-ststistic value : ' , r2/mse)

print()
print()
mae = metrics.mean_absolute_error(y_train, x_pred)
mse = metrics.mean_squared_error(y_train, x_pred)
r2 = np.sqrt(metrics.mean_squared_error(y_train, x_pred))
r_squared = reg_model.score(X, y)


print('Mean Absolute Error:', mae)
print('Mean Square Error:', mse)
print('Root Mean Square Error:', r2)
print('R^2 value :', r_squared)
# print('Adjusted R^2 value : ' , adjusted_r^2)
# Out:
# Mean Absolute Error: 0.16741917981078855
# Mean Square Error: 0.04255333333150812
# Root Mean Square Error: 0.20628459305413024
# R^2 value : 0.35958631990925605
# F-ststistic value :  4.847671778074063
#
#
# Mean Absolute Error: 0.15620826374207983
# Mean Square Error: 0.03895290302636829
# Root Mean Square Error: 0.19736489816167485
# R^2 value : 0.35958631990925605

# %%
#display adjusted R-squared
1 - (1-reg_model.score(X, y))*(len(y)-1)/(len(y)-X.shape[1]-1)
# Out:
# 0.3560171353864573

# %%
import statsmodels.api as sm
X_train=sm.add_constant(X_train)
model=sm.OLS(y_train,X_train).fit()
p_values=model.summary2().tables[1]['P>|t|']
p_values
# Out:
# const    1.187040e-08
# x1       9.420271e-01
# x2       5.322399e-04
# x3       2.574567e-59
# x4       7.279839e-01
# x5       2.574567e-59
# x6       7.279839e-01
# x7       2.168613e-47
# Name: P>|t|, dtype: float64

# %%
len(li)
# Out:
# 7

# %%
# import itertools


# all_columns = li;

# num_columns_to_select = 7


# column_combinations = list(itertools.combinations(all_columns, num_columns_to_select))

# # column_combinations
# for combination in column_combinations:
#     X=df[list(combination)]
#     y = df['CPI']
#     scaler = StandardScaler()
#     X=scaler.fit_transform(X)
#     X_train,X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 100)
#     reg_model = linear_model.LinearRegression()
#     reg_model.fit(X_train,y_train)
#     count=0
#     flag=0
#     for j in  reg_model.coef_:
#         if j>=0:
#             count+=1
#     if count==6:
#         print(combination)

# %%
list(zip(X, reg_model.coef_))
# Out:
# [(array([0.09712063, 0.45394737, 0.07258351, 0.16613134, 0.07258351,
#          0.16613134, 0.85482389]),
#   0.005362320035846993),
#  (array([0.13110489, 0.41447368, 0.18818352, 0.2436626 , 0.18818352,
#          0.2436626 , 0.55001455]),
#   -0.2281581467210392),
#  (array([0.06310982, 0.32894737, 0.04329776, 0.23807877, 0.04329776,
#          0.23807877, 0.60647682]),
#   0.450236239893555),
#  (array([0.00326567, 0.39638158, 0.10191846, 0.17329644, 0.10191846,
#          0.17329644, 0.60375236]),
#   0.009210686749866068),
#  (array([0.00545607, 0.41282895, 0.06011446, 0.20650294, 0.06011446,
#          0.20650294, 0.85105933]),
#   0.45023623989355477),
#  (array([0.12047153, 0.30427632, 0.09957114, 0.1645995 , 0.09957114,
#          0.1645995 , 0.86593755]),
#   0.009210686749866123),
#  (array([0.07400868, 0.40460526, 0.01346309, 0.1505658 , 0.01346309,
#          0.1505658 , 0.94838862]),
#   0.5038030597907854)]

# %%
reg_model.coef_
# Out:
# array([ 0.00536232, -0.22815815,  0.45023624,  0.00921069,  0.45023624,
#         0.00921069,  0.50380306])

# %%
count=0
flag=0
for j in  reg_model.coef_:
    if j>=0:
        count+=1
    
count
# Out:
# 6
